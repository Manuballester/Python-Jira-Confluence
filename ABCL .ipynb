# %%
# -*- coding: utf-8 -*-
"""
@author: Manuballester

Read the docs will guide you.
https://jira.readthedocs.io/en/master/

This script will create a Confluence page containing the As Built Configuration of the satellite. Here are included the 
Assemblies and the components contained in them.

"""

import os
from jira import JIRA
from jira.client import ResultList
from jira.resources import Issue
from atlassian import Confluence
import pandas as pd
import csv

#Do not put your credentials here. At the moment use env variables, but when we have the secret vault, use it and please purge old tokens.
user = os.environ['JiraUser'] 
apikey = os.environ['JiraToken2']
server = 'https://iceyedev.atlassian.net/'

#Note, when using user specific token, the same token is for all your instances. Not just test or production. Act accordingly.
options = {
 'server': server
}

jira = JIRA(options, basic_auth=(user,apikey))

#Modify here the name of the satellite which you want to obtain the As Built Configuration: 
name = 'P212'

search = '"Epic Link" = "ICEYE-' + str(name) + '" and summary ~ "assembly" ORDER BY summary'
issues_in_proj = jira.search_issues(search, startAt = 0, maxResults = 80)   

ABCL = ""
comps = ""
lista = ""

csvname = str(name) + '_ABCL.csv'

# Write in CSV 
with open(csvname, 'w', newline='') as csvfile:
    fieldnames = ['Assembly', 'Components']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    
    for i in issues_in_proj:
        issue = jira.issue(i)
        ABCL = str(issue.permalink()) + "\n" # str(issue.fields.summary) + ": " +

        searcheck = ' issue in linkedIssues(' + str(issue) + ', "is blocked by") '
        issuescheck = jira.search_issues(searcheck)

        if issuescheck != []:
            continue

        search2 = ' issue in linkedIssues(' + str(issue) + ', "blocks") '
        issues_in_proj2 = jira.search_issues(search2)  

        for j in issues_in_proj2:
            issue2 = jira.issue(j)
            summ = issue2.fields.summary
            nn = issue2.permalink()

            search3 = ' issue in linkedIssues(' + str(issue2) + ', "blocks") '
            issues_in_proj3 = jira.search_issues(search3) 
            if issues_in_proj3 == []:
                comp = str(nn) 
                comps = comps + comp + "\n"
                comp = ""
            else:
                comp = str(nn)  
                comps = comps + comp + "\n"
                comp = ""

            for k in issues_in_proj3:
                issue3 = jira.issue(k)
                summ = issue3.fields.summary
                nn = issue3.permalink()
                comp = str(nn)
                comps = comps + comp + "\n"
                comp = ""

        writer.writerow({'Assembly': ABCL, 'Components': comps})
        lista = lista + ABCL + comps + "\n\n"
        comps = ""

print(lista)

# confluence.create_page(space="SMS", title="ABCL X12", body='', parent_id=None, type='page', representation='storage', editor='v2')

#Update the Confluence page with all the components information:
# confluence = Confluence(url = server,
#     username = user,
#     password = apikey,
#     cloud = True)

# idpage = confluence.get_page_id(space="SMS", title="ABCL X12")
# status = confluence.update_page(
#     parent_id = None,
#     page_id = idpage,
#     title = "ABCL X12",
#     body = lista
# )
# Out:
# https://iceyedev.atlassian.net/browse/AIVL-1111
# https://iceyedev.atlassian.net/browse/AIVL-1255
# https://iceyedev.atlassian.net/browse/AIVL-1254
# https://iceyedev.atlassian.net/browse/AIVL-1253
# https://iceyedev.atlassian.net/browse/AIVL-1252
# https://iceyedev.atlassian.net/browse/AIVL-1251
# https://iceyedev.atlassian.net/browse/AIVL-1250
# https://iceyedev.atlassian.net/browse/AIVL-1249
# https://iceyedev.atlassian.net/browse/AIVL-1248
# https://iceyedev.atlassian.net/browse/AIVL-1247
# https://iceyedev.atlassian.net/browse/AIVL-1246
# https://iceyedev.atlassian.net/browse/AIVL-885
#
#
# https://iceyedev.atlassian.net/browse/AIVL-1102
#
#
# https://iceyedev.atlassian.net/browse/AIVL-1093
#
#
# https://iceyedev.atlassian.net/browse/AIVL-1094
# https://iceyedev.atlassian.net/browse/AIVL-491
# https://iceyedev.atlassian.net/browse/AIVL-478
# https://iceyedev.atlassian.net/browse/AIVL-420
#
#
# https://iceyedev.atlassian.net/browse/AIVL-1110
#
#
# https://iceyedev.atlassian.net/browse/AIVL-1108
#
#
# https://iceyedev.atlassian.net/browse/AIVL-1117
# https://iceyedev.atlassian.net/browse/AIVL-731
# https://iceyedev.atlassian.net/browse/AIVL-728
# https://iceyedev.atlassian.net/browse/AIVL-719
# https://iceyedev.atlassian.net/browse/AIVL-553
# https://iceyedev.atlassian.net/browse/AIVL-551
#
#
# https://iceyedev.atlassian.net/browse/AIVL-1097
# https://iceyedev.atlassian.net/browse/AIVL-756
# https://iceyedev.atlassian.net/browse/AIVL-718
# https://iceyedev.atlassian.net/browse/AIVL-713
#
#
# https://iceyedev.atlassian.net/browse/AIVL-1107
#
#
# https://iceyedev.atlassian.net/browse/AIVL-1098
#
#
# https://iceyedev.atlassian.net/browse/AIVL-1183
# https://iceyedev.atlassian.net/browse/AIVL-442
#
#
# https://iceyedev.atlassian.net/browse/AIVL-1184
# https://iceyedev.atlassian.net/browse/AIVL-443
#
#
# https://iceyedev.atlassian.net/browse/AIVL-1185
# https://iceyedev.atlassian.net/browse/AIVL-434
#
#
# https://iceyedev.atlassian.net/browse/AIVL-1186
# https://iceyedev.atlassian.net/browse/AIVL-443
#
#
# https://iceyedev.atlassian.net/browse/AIVL-1106
#
#
# https://iceyedev.atlassian.net/browse/AIVL-1112
# https://iceyedev.atlassian.net/browse/AIVL-1346
# https://iceyedev.atlassian.net/browse/AIVL-785
# https://iceyedev.atlassian.net/browse/AIVL-613
# https://iceyedev.atlassian.net/browse/AIVL-57
# https://iceyedev.atlassian.net/browse/AIVL-1326
# https://iceyedev.atlassian.net/browse/AIVL-830
# https://iceyedev.atlassian.net/browse/AIVL-612
# https://iceyedev.atlassian.net/browse/AIVL-581
# https://iceyedev.atlassian.net/browse/AIVL-1325
# https://iceyedev.atlassian.net/browse/AIVL-788
# https://iceyedev.atlassian.net/browse/AIVL-581
# https://iceyedev.atlassian.net/browse/AIVL-577
# https://iceyedev.atlassian.net/browse/AIVL-1324
# https://iceyedev.atlassian.net/browse/AIVL-819
# https://iceyedev.atlassian.net/browse/AIVL-630
# https://iceyedev.atlassian.net/browse/AIVL-610
# https://iceyedev.atlassian.net/browse/AIVL-1323
# https://iceyedev.atlassian.net/browse/AIVL-829
# https://iceyedev.atlassian.net/browse/AIVL-652
# https://iceyedev.atlassian.net/browse/AIVL-609
# https://iceyedev.atlassian.net/browse/AIVL-1322
# https://iceyedev.atlassian.net/browse/AIVL-824
# https://iceyedev.atlassian.net/browse/AIVL-637
# https://iceyedev.atlassian.net/browse/AIVL-607
# https://iceyedev.atlassian.net/browse/AIVL-1321
# https://iceyedev.atlassian.net/browse/AIVL-826
# https://iceyedev.atlassian.net/browse/AIVL-645
# https://iceyedev.atlassian.net/browse/AIVL-608
# https://iceyedev.atlassian.net/browse/AIVL-1320
# https://iceyedev.atlassian.net/browse/AIVL-915
# https://iceyedev.atlassian.net/browse/AIVL-787
# https://iceyedev.atlassian.net/browse/AIVL-632
# https://iceyedev.atlassian.net/browse/AIVL-1319
# https://iceyedev.atlassian.net/browse/AIVL-897
# https://iceyedev.atlassian.net/browse/AIVL-763
# https://iceyedev.atlassian.net/browse/AIVL-584
# https://iceyedev.atlassian.net/browse/AIVL-1318
# https://iceyedev.atlassian.net/browse/AIVL-896
# https://iceyedev.atlassian.net/browse/AIVL-766
# https://iceyedev.atlassian.net/browse/AIVL-590
# https://iceyedev.atlassian.net/browse/AIVL-1317
# https://iceyedev.atlassian.net/browse/AIVL-895
# https://iceyedev.atlassian.net/browse/AIVL-821
# https://iceyedev.atlassian.net/browse/AIVL-651
# https://iceyedev.atlassian.net/browse/AIVL-1316
# https://iceyedev.atlassian.net/browse/AIVL-893
# https://iceyedev.atlassian.net/browse/AIVL-786
# https://iceyedev.atlassian.net/browse/AIVL-575
# https://iceyedev.atlassian.net/browse/AIVL-1315
# https://iceyedev.atlassian.net/browse/AIVL-914
# https://iceyedev.atlassian.net/browse/AIVL-784
# https://iceyedev.atlassian.net/browse/AIVL-632
# https://iceyedev.atlassian.net/browse/AIVL-1314
# https://iceyedev.atlassian.net/browse/AIVL-820
# https://iceyedev.atlassian.net/browse/AIVL-597
# https://iceyedev.atlassian.net/browse/AIVL-570
# https://iceyedev.atlassian.net/browse/AIVL-1313
# https://iceyedev.atlassian.net/browse/AIVL-901
# https://iceyedev.atlassian.net/browse/AIVL-784
# https://iceyedev.atlassian.net/browse/AIVL-624
# https://iceyedev.atlassian.net/browse/AIVL-1312
# https://iceyedev.atlassian.net/browse/AIVL-899
# https://iceyedev.atlassian.net/browse/AIVL-822
# https://iceyedev.atlassian.net/browse/AIVL-633
# https://iceyedev.atlassian.net/browse/AIVL-1311
# https://iceyedev.atlassian.net/browse/AIVL-900
# https://iceyedev.atlassian.net/browse/AIVL-823
# https://iceyedev.atlassian.net/browse/AIVL-628
# https://iceyedev.atlassian.net/browse/AIVL-1310
# https://iceyedev.atlassian.net/browse/AIVL-898
# https://iceyedev.atlassian.net/browse/AIVL-833
# https://iceyedev.atlassian.net/browse/AIVL-592
# https://iceyedev.atlassian.net/browse/AIVL-1309
# https://iceyedev.atlassian.net/browse/AIVL-903
# https://iceyedev.atlassian.net/browse/AIVL-831
# https://iceyedev.atlassian.net/browse/AIVL-635
#
#
# https://iceyedev.atlassian.net/browse/AIVL-1109
#
#
# https://iceyedev.atlassian.net/browse/AIVL-1095
# https://iceyedev.atlassian.net/browse/AIVL-673
# https://iceyedev.atlassian.net/browse/AIVL-658
# https://iceyedev.atlassian.net/browse/AIVL-492
# https://iceyedev.atlassian.net/browse/NCR-517
# https://iceyedev.atlassian.net/browse/AIVL-428
#
#
# https://iceyedev.atlassian.net/browse/AIVL-1101
#
#
# https://iceyedev.atlassian.net/browse/AIVL-1113
# https://iceyedev.atlassian.net/browse/NCR-653
# https://iceyedev.atlassian.net/browse/AIVL-500
# https://iceyedev.atlassian.net/browse/AIVL-498
# https://iceyedev.atlassian.net/browse/AIVL-497
# https://iceyedev.atlassian.net/browse/AIVL-496
# https://iceyedev.atlassian.net/browse/AIVL-495
#
#
# https://iceyedev.atlassian.net/browse/AIVL-1100
#
#
# https://iceyedev.atlassian.net/browse/AIVL-1105
#
#
# https://iceyedev.atlassian.net/browse/MITA-146

# %%
# -*- coding: utf-8 -*-
"""
@author: Manuballester

Read the docs will guide you.
https://jira.readthedocs.io/en/master/

This script will create a Confluence page containing the As Built Configuration of the satellite. Here are included the 
Assemblies and the components contained in them.

"""

import os
from jira import JIRA
from jira.client import ResultList
from jira.resources import Issue
from atlassian import Confluence
import pandas as pd
import csv

#Do not put your credentials here. At the moment use env variables, but when we have the secret vault, use it and please purge old tokens.
user = os.environ['JiraUser'] 
apikey = os.environ['JiraToken2']
server = 'https://iceyedev.atlassian.net/'

#Note, when using user specific token, the same token is for all your instances. Not just test or production. Act accordingly.
options = {
 'server': server
}

jira = JIRA(options, basic_auth=(user,apikey))

#Modify here the name of the satellite which you want to obtain the As Built Configuration: 
name = 'P212'

search = '"Epic Link" = "ICEYE-' + str(name) + '" and summary ~ "assembly" ORDER BY summary'
issues_in_proj = jira.search_issues(search, startAt = 0, maxResults = 80)   

ABCL = ""
comps = ""
lista = ""

csvname = str(name) + '_ABCL.csv'

# Write in CSV 
with open(csvname, 'w', newline='') as csvfile:
    fieldnames = ['Assembly', 'Components']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    
    for i in issues_in_proj:
        issue = jira.issue(i)
        ABCL = str(issue.permalink()) + "\n" # str(issue.fields.summary) + ": " +

        searcheck = ' issue in linkedIssues(' + str(issue) + ', "is blocked by") '
        issuescheck = jira.search_issues(searcheck)

        if issuescheck != []:
            continue

        search2 = ' issue in linkedIssues(' + str(issue) + ', "blocks") '
        issues_in_proj2 = jira.search_issues(search2)  

        for j in issues_in_proj2:
            issue2 = jira.issue(j)
            summ = issue2.fields.summary
            nn = issue2.permalink()

            search3 = ' issue in linkedIssues(' + str(issue2) + ', "blocks") '
            issues_in_proj3 = jira.search_issues(search3) 
            if issues_in_proj3 == []:
                comp = str(nn) 
                comps = comps + comp + "\n"
                comp = ""
            else:
                comp = str(nn)  
                comps = comps + comp + "\n"
                comp = ""

            for k in issues_in_proj3:
                issue3 = jira.issue(k)
                summ = issue3.fields.summary
                nn = issue3.permalink()
                comp = str(nn)
                comps = comps + comp + "\n"
                comp = ""

        writer.writerow({'Assembly': ABCL, 'Components': comps})
        lista = lista + ABCL + comps + "\n\n"
        comps = ""

print(lista)

# confluence.create_page(space="SMS", title="ABCL X12", body='', parent_id=None, type='page', representation='storage', editor='v2')

#Update the Confluence page with all the components information:
confluence = Confluence(url = server,
    username = user,
    password = apikey,
    cloud = True)

idpage = confluence.get_page_id(space="SMS", title="ABCL X12")



status = confluence.update_page(
    parent_id = None,
    page_id = idpage,
    title = "ABCL X12",
    body = lista
)

# %%
import os
import json
from atlassian import Confluence
import pandas as pd
import csv
import sys


def main():
    '''
        csvtoconfluence converts a csv file to markup for confluence
        usage: python csvtoconfluence.py <csv>
        Output will be a .txt file with cut/pastable text in markup for
        confluence
    '''
    inputfile = sys.argv[1]
    outputname = inputfile.replace('.csv', '.txt')

    # assumes first line is header
    firstrow = True
    with open(outputname, 'wb') as fileout:
        with open(inputfile, 'r') as infile:
            readfile = csv.reader(infile)
            for row in readfile:
                if firstrow:
                    firstrow = False
                    for item in row:
                        fileout.write('||{0}'.format(item))
                    fileout.write('||')
                else:
                    for item in row:
                        if item == '':
                            # use blank space to avoid header style formating
                            fileout.write('|{0: <1}'.format(item))
                        else:
                            fileout.write('|{0}'.format(item))
                    fileout.write('|')
                fileout.write('\n')
    fileout.close()
    infile.close()


if __name__ == '__main__':
    main()
